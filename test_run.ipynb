# %%
from lib.tripping import trip_operation
from lib.circulation import circl
import numpy as np

total_lengths = [12500]
wob = 0

hook_POOH_0     = [trip_operation(wob, flowrate=50, length=i, operation='POOH') for i in total_lengths]
hook_RIH_0      = [trip_operation(wob, flowrate=50, length=i, operation='RIH') for i in total_lengths]
hook_ROB_0      = [trip_operation(wob, flowrate=50, length=i, operation='ROB') for i in total_lengths]
hook_POOH_500   = [trip_operation(wob, flowrate=500, length=i, operation='POOH') for i in total_lengths]
hook_RIH_500    = [trip_operation(wob, flowrate=500, length=i, operation='RIH') for i in total_lengths]
hook_ROB_500    = [trip_operation(wob, flowrate=500, length=i, operation='ROB') for i in total_lengths]
hook_POOH_600   = [trip_operation(wob, flowrate=600, length=i, operation='POOH') for i in total_lengths]
hook_RIH_600    = [trip_operation(wob, flowrate=600, length=i, operation='RIH') for i in total_lengths]
hook_ROB_600    = [trip_operation(wob, flowrate=600, length=i, operation='ROB') for i in total_lengths]
# Out:
# c:\Users\Elmir\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Web Extension extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

fig = make_subplots(rows=1, cols=3, subplot_titles=("@ 600 GPM", "@ 500 GPM", "@ 50 GPM"), shared_yaxes=True)

fig.add_trace(go.Scatter(x=hook_POOH_600[0]+50000, y=np.linspace(12500, 0, len(hook_POOH_600[0])), name='POOH 600 gpm', line=dict(color='darkred', width=3, dash='dashdot')), row=1, col=1)
fig.add_trace(go.Scatter(x=hook_RIH_600[0]+50000, y=np.linspace(12500, 0, len(hook_RIH_600[0])), name='RIH 600 gpm', line=dict(color='orange', width=3, dash='dashdot')), row=1, col=1) 
fig.add_trace(go.Scatter(x=hook_ROB_600[0]+50000, y=np.linspace(12500, 0, len(hook_ROB_600[0])), name='ROB 600 gpm', line=dict(color='navy', width=3, dash='dashdot')), row=1, col=1) 
fig.add_trace(go.Scatter(x=hook_POOH_500[0]+50000, y=np.linspace(12500, 0, len(hook_POOH_500[0])), name='POOH 500 gpm', line=dict(color='sienna', width=3, dash='dash')), row=1, col=2)
fig.add_trace(go.Scatter(x=hook_RIH_500[0]+50000, y=np.linspace(12500, 0, len(hook_RIH_500[0])), name='RIH 500 gpm', line=dict(color='sandybrown', width=3, dash='dash')), row=1, col=2) 
fig.add_trace(go.Scatter(x=hook_ROB_500[0]+50000, y=np.linspace(12500, 0, len(hook_ROB_500[0])), name='ROB 500 gpm', line=dict(color='seagreen', width=3, dash='dash')), row=1, col=2) 
fig.add_trace(go.Scatter(x=hook_POOH_0[0]+50000, y=np.linspace(12500, 0, len(hook_POOH_0[0])), name='POOH 50 gpm', line=dict(color='turquoise', width=3, dash='dot')), row=1, col=3)
fig.add_trace(go.Scatter(x=hook_RIH_0[0]+50000, y=np.linspace(12500, 0, len(hook_RIH_0[0])), name='RIH 50 gpm', line=dict(color='wheat', width=3, dash='dot')), row=1, col=3) 
fig.add_trace(go.Scatter(x=hook_ROB_0[0]+50000, y=np.linspace(12500, 0, len(hook_ROB_0[0])), name='ROB 50 gpm', line=dict(color='violet', width=3, dash='dot')), row=1, col=3) 

# Update the layout for white background and improved readability
fig.update_xaxes(minor=dict(ticklen=6, tickcolor="black", showgrid=True))
fig.update_yaxes(minor_ticks="inside")
fig.update_layout(
    
    template= "none",
    title='Axial Force vs. DP Length (without friction forces and fluid forces)',  # Add a title
    title_font_size=24,
    xaxis2=dict(
        title='Axial Force [lbf]',
        titlefont_size=20,
        tickfont_size=14,
    ),
    yaxis=dict(
        title='DP [ft]',
        titlefont_size=20,
        tickfont_size=14,
        autorange="reversed"
    ),
    legend=dict(
        traceorder='normal',
        font=dict(
            size=16,
        )
    ),
    height = 600,
    width = 1400
)

# Show the figure
fig.show()
# fig.write_html("Plot.html")

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

fig = make_subplots(rows=1, cols=3, subplot_titles=("@ 600 GPM", "@ 500 GPM", "@ 50 GPM"), shared_yaxes=True)

fig.add_trace(go.Scatter(x=hook_POOH_600[0]+50000, y=np.linspace(12500, 0, len(hook_POOH_600[0])), name='POOH 600 gpm', line=dict(color='darkred', width=3, dash='dashdot')), row=1, col=1)
fig.add_trace(go.Scatter(x=hook_RIH_600[0]+50000, y=np.linspace(12500, 0, len(hook_RIH_600[0])), name='RIH 600 gpm', line=dict(color='orange', width=3, dash='dashdot')), row=1, col=1) 
fig.add_trace(go.Scatter(x=hook_ROB_600[0]+50000, y=np.linspace(12500, 0, len(hook_ROB_600[0])), name='ROB 600 gpm', line=dict(color='navy', width=3, dash='dashdot')), row=1, col=1) 
fig.add_trace(go.Scatter(x=hook_POOH_500[0]+50000, y=np.linspace(12500, 0, len(hook_POOH_500[0])), name='POOH 500 gpm', line=dict(color='sienna', width=3, dash='dash')), row=1, col=2)
fig.add_trace(go.Scatter(x=hook_RIH_500[0]+50000, y=np.linspace(12500, 0, len(hook_RIH_500[0])), name='RIH 500 gpm', line=dict(color='sandybrown', width=3, dash='dash')), row=1, col=2) 
fig.add_trace(go.Scatter(x=hook_ROB_500[0]+50000, y=np.linspace(12500, 0, len(hook_ROB_500[0])), name='ROB 500 gpm', line=dict(color='seagreen', width=3, dash='dash')), row=1, col=2) 
fig.add_trace(go.Scatter(x=hook_POOH_0[0]+50000, y=np.linspace(12500, 0, len(hook_POOH_0[0])), name='POOH 50 gpm', line=dict(color='turquoise', width=3, dash='dot')), row=1, col=3)
fig.add_trace(go.Scatter(x=hook_RIH_0[0]+50000, y=np.linspace(12500, 0, len(hook_RIH_0[0])), name='RIH 50 gpm', line=dict(color='wheat', width=3, dash='dot')), row=1, col=3) 
fig.add_trace(go.Scatter(x=hook_ROB_0[0]+50000, y=np.linspace(12500, 0, len(hook_ROB_0[0])), name='ROB 50 gpm', line=dict(color='violet', width=3, dash='dot')), row=1, col=3) 

# Update the layout for white background and improved readability
fig.update_xaxes(minor=dict(ticklen=6, tickcolor="black", showgrid=True))
fig.update_yaxes(minor_ticks="inside")
fig.update_layout(
    
    template= "none",
    title='Axial Force vs. DP Length (+ Fluid Force)',  # Add a title
    title_font_size=24,
    xaxis2=dict(
        title='Axial Force [lbf]',
        titlefont_size=20,
        tickfont_size=14,
    ),
    yaxis=dict(
        title='DP [ft]',
        titlefont_size=20,
        tickfont_size=14,
        autorange="reversed"
    ),
    legend=dict(
        traceorder='normal',
        font=dict(
            size=16,
        )
    ),
    height = 600,
    width = 1400
)

# Show the figure
fig.show()
# fig.write_html("Plot.html")

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

fig = make_subplots(rows=1, cols=3, subplot_titles=("@ 600 GPM", "@ 500 GPM", "@ 50 GPM"), shared_yaxes=True)

fig.add_trace(go.Scatter(x=hook_POOH_600[0]+50000, y=np.linspace(12500, 0, len(hook_POOH_600[0])), name='POOH 600 gpm', line=dict(color='darkred', width=3, dash='dashdot')), row=1, col=1)
fig.add_trace(go.Scatter(x=hook_RIH_600[0]+50000, y=np.linspace(12500, 0, len(hook_RIH_600[0])), name='RIH 600 gpm', line=dict(color='orange', width=3, dash='dashdot')), row=1, col=1) 
fig.add_trace(go.Scatter(x=hook_ROB_600[0]+50000, y=np.linspace(12500, 0, len(hook_ROB_600[0])), name='ROB 600 gpm', line=dict(color='navy', width=3, dash='dashdot')), row=1, col=1) 
fig.add_trace(go.Scatter(x=hook_POOH_500[0]+50000, y=np.linspace(12500, 0, len(hook_POOH_500[0])), name='POOH 500 gpm', line=dict(color='sienna', width=3, dash='dash')), row=1, col=2)
fig.add_trace(go.Scatter(x=hook_RIH_500[0]+50000, y=np.linspace(12500, 0, len(hook_RIH_500[0])), name='RIH 500 gpm', line=dict(color='sandybrown', width=3, dash='dash')), row=1, col=2) 
fig.add_trace(go.Scatter(x=hook_ROB_500[0]+50000, y=np.linspace(12500, 0, len(hook_ROB_500[0])), name='ROB 500 gpm', line=dict(color='seagreen', width=3, dash='dash')), row=1, col=2) 
fig.add_trace(go.Scatter(x=hook_POOH_0[0]+50000, y=np.linspace(12500, 0, len(hook_POOH_0[0])), name='POOH 50 gpm', line=dict(color='turquoise', width=3, dash='dot')), row=1, col=3)
fig.add_trace(go.Scatter(x=hook_RIH_0[0]+50000, y=np.linspace(12500, 0, len(hook_RIH_0[0])), name='RIH 50 gpm', line=dict(color='wheat', width=3, dash='dot')), row=1, col=3) 
fig.add_trace(go.Scatter(x=hook_ROB_0[0]+50000, y=np.linspace(12500, 0, len(hook_ROB_0[0])), name='ROB 50 gpm', line=dict(color='violet', width=3, dash='dot')), row=1, col=3) 

# Update the layout for white background and improved readability
fig.update_xaxes(minor=dict(ticklen=6, tickcolor="black", showgrid=True))
fig.update_yaxes(minor_ticks="inside")
fig.update_layout(
    
    template= "none",
    title='Axial Force vs. DP Length (+ Friction Force)',  # Add a title
    title_font_size=24,
    xaxis2=dict(
        title='Axial Force [lbf]',
        titlefont_size=20,
        tickfont_size=14,
    ),
    yaxis=dict(
        title='DP [ft]',
        titlefont_size=20,
        tickfont_size=14,
        autorange="reversed"
    ),
    legend=dict(
        traceorder='normal',
        font=dict(
            size=16,
        )
    ),
    height = 600,
    width = 1400
)

# Show the figure
fig.show()
# fig.write_html("Plot.html")

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

fig = make_subplots(rows=1, cols=3, subplot_titles=("@ 600 GPM", "@ 500 GPM", "@ 50 GPM"), shared_yaxes=True)

fig.add_trace(go.Scatter(x=hook_POOH_600[0]+50000, y=np.linspace(12500, 0, len(hook_POOH_600[0])), name='POOH 600 gpm', line=dict(color='darkred', width=3, dash='dashdot')), row=1, col=1)
fig.add_trace(go.Scatter(x=hook_RIH_600[0]+50000, y=np.linspace(12500, 0, len(hook_RIH_600[0])), name='RIH 600 gpm', line=dict(color='orange', width=3, dash='dashdot')), row=1, col=1) 
fig.add_trace(go.Scatter(x=hook_ROB_600[0]+50000, y=np.linspace(12500, 0, len(hook_ROB_600[0])), name='ROB 600 gpm', line=dict(color='navy', width=3, dash='dashdot')), row=1, col=1) 
fig.add_trace(go.Scatter(x=hook_POOH_500[0]+50000, y=np.linspace(12500, 0, len(hook_POOH_500[0])), name='POOH 500 gpm', line=dict(color='sienna', width=3, dash='dash')), row=1, col=2)
fig.add_trace(go.Scatter(x=hook_RIH_500[0]+50000, y=np.linspace(12500, 0, len(hook_RIH_500[0])), name='RIH 500 gpm', line=dict(color='sandybrown', width=3, dash='dash')), row=1, col=2) 
fig.add_trace(go.Scatter(x=hook_ROB_500[0]+50000, y=np.linspace(12500, 0, len(hook_ROB_500[0])), name='ROB 500 gpm', line=dict(color='seagreen', width=3, dash='dash')), row=1, col=2) 
fig.add_trace(go.Scatter(x=hook_POOH_0[0]+50000, y=np.linspace(12500, 0, len(hook_POOH_0[0])), name='POOH 50 gpm', line=dict(color='turquoise', width=3, dash='dot')), row=1, col=3)
fig.add_trace(go.Scatter(x=hook_RIH_0[0]+50000, y=np.linspace(12500, 0, len(hook_RIH_0[0])), name='RIH 50 gpm', line=dict(color='wheat', width=3, dash='dot')), row=1, col=3) 
fig.add_trace(go.Scatter(x=hook_ROB_0[0]+50000, y=np.linspace(12500, 0, len(hook_ROB_0[0])), name='ROB 50 gpm', line=dict(color='violet', width=3, dash='dot')), row=1, col=3) 

# Update the layout for white background and improved readability
fig.update_xaxes(minor=dict(ticklen=6, tickcolor="black", showgrid=True))
fig.update_yaxes(minor_ticks="inside")
fig.update_layout(
    
    template= "none",
    title='Axial Force vs. DP Length (+ Friction Force + Fluid Force)',  # Add a title
    title_font_size=24,
    xaxis2=dict(
        title='Axial Force [lbf]',
        titlefont_size=20,
        tickfont_size=14,
    ),
    yaxis=dict(
        title='DP [ft]',
        titlefont_size=20,
        tickfont_size=14,
        autorange="reversed"
    ),
    legend=dict(
        traceorder='normal',
        font=dict(
            size=16,
        )
    ),
    height = 600,
    width = 1400
)

# Show the figure
fig.show()
# fig.write_html("Plot.html")

# %%
import plotly.graph_objects as go

trips = ['POOH']
fig = go.Figure()

fig.add_trace(go.Bar(
    x=trips,
    y=[366672],
    name='Clearance - 1 in',
    marker_color='#ae2012',
    text=[366672],
    textposition='auto'
))

fig.add_trace(go.Bar(
    x=trips,
    y=[370948],
    name='Clearance - 3 in',
    marker_color='#e07a5f',
    text=[370948],
    textposition='auto'
))

fig.add_trace(go.Bar(
    x=trips,
    y=[374622],
    name='Clearance - 5 in',
    marker_color='#3d405b',
    text=[374622],
    textposition='auto'
))

fig.add_trace(go.Bar(
    x=trips,
    y=[376142],
    name='Clearance - 7 in',
    marker_color='#81b29a',
    text=[376142],
    textposition='auto'
))

fig.update_layout(
    barmode='group', 
    template= "none",
    title='Hookload with different restrictions @ 550 gpm',
    title_font_size=24,
    xaxis=dict(
        titlefont_size=20
    ),
    yaxis=dict(
        title='Hookload [lbf]',
        titlefont_size=20
    ),
    legend=dict(
        traceorder='normal',
        font=dict(
            size=16,
        )
    ),
    height=600, 
    width=800
    )

fig.show()

# %%
from lib.init_xls import pressure_gradient
from lib.constants import Calculations

clc = Calculations(lengths=12500)
P_drop_outer, v_i, v_o = pressure_gradient(
        Q=600,
        rho=clc.mud_density_ppg, 
        mu_p=clc.visc_p, 
        tao=clc.tao_y,
        D_o=clc.global_od_array,
        D_i=clc.global_id_array, 
        D_w=clc.global_hole_array
    )

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

fig1 = make_subplots(rows=1, cols=3, shared_yaxes=True, shared_xaxes=True)

fig1.add_trace(go.Scatter(x=P_drop_outer, y=np.linspace(0, 12500, len(P_drop_outer)), name='Pressure Gradient', line=dict(color='darkred', width=3, dash='dashdot')), row=1, col=1)
fig1.add_trace(go.Scatter(x=v_i, y=np.linspace(0, 12500, len(v_i)), name='Inner Velocity', line=dict(color='orange', width=3, dash='dashdot')), row=1, col=2)
fig1.add_trace(go.Scatter(x=v_o, y=np.linspace(0, 12500, len(v_o)), name='Outer Velocity', line=dict(color='navy', width=3, dash='dash')), row=1, col=3)
# fig1.add_trace(go.Scatter(x=flu_250_17k, y=np.linspace(17000,0,len(flu_250_17k)), name='17k @ 250 gpm', line=dict(color='teal', width=3, dash='dash')), row=1, col=2)

# Update the layout

fig1.update_layout(
    
    template= "none",
    title='',
    title_font_size=24,
    xaxis2=dict(
        title='Fluid Force [lbf]',
        titlefont_size=20
    ),
    yaxis=dict(
        title='DP [ft]',
        titlefont_size=20,
        autorange="reversed"
    ),
    # xaxis2=dict(
    #     title='Fluid Force [lbf]',
    #     titlefont_size=20
    # ),
    # yaxis2=dict(
    #     title='Bit Depth [ft]',
    #     titlefont_size=20,
    #     autorange="reversed"
    # ),
    legend=dict(
        traceorder='normal',
        font=dict(
            size=16,
        )
    ),
    height = 600,
    width = 1000
)

fig1.show()
# fig.write_html("Plot.html")

# %%
from lib.circulation import circl
import numpy as np
# total_lengths = np.arange(12500, 18001, 100)
flu_600 = circl(flowrate=600, length=12500)
flu_500 = circl(flowrate=500, length=12500)
flu_100 = circl(flowrate=50, length=12500)

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

fig1 = make_subplots(rows=1, cols=3, shared_yaxes=True, shared_xaxes=True)

fig1.add_trace(go.Scatter(x=flu_600, y=np.linspace(0, 12500, len(flu_600)), name='@ 600 gpm', line=dict(color='darkred', width=3, dash='dashdot')), row=1, col=1)
fig1.add_trace(go.Scatter(x=flu_500, y=np.linspace(0, 12500, len(flu_500)), name='@ 500 gpm', line=dict(color='orange', width=3, dash='dashdot')), row=1, col=2)
fig1.add_trace(go.Scatter(x=flu_100, y=np.linspace(0, 12500, len(flu_100)), name='@ 50 gpm', line=dict(color='navy', width=3, dash='dash')), row=1, col=3)
# fig1.add_trace(go.Scatter(x=flu_250_17k, y=np.linspace(17000,0,len(flu_250_17k)), name='17k @ 250 gpm', line=dict(color='teal', width=3, dash='dash')), row=1, col=2)

# Update the layout

fig1.update_layout(
    
    template= "none",
    title='Fluid Force for Various GPM Rates',
    title_font_size=24,
    xaxis2=dict(
        title='Fluid Force [lbf]',
        titlefont_size=20
    ),
    yaxis=dict(
        title='Bit Depth [ft]',
        titlefont_size=20,
        autorange="reversed"
    ),
    # xaxis2=dict(
    #     title='Fluid Force [lbf]',
    #     titlefont_size=20
    # ),
    # yaxis2=dict(
    #     title='Bit Depth [ft]',
    #     titlefont_size=20,
    #     autorange="reversed"
    # ),
    legend=dict(
        traceorder='normal',
        font=dict(
            size=16,
        )
    ),
    height = 600,
    width = 1000
)

fig1.show()
# fig.write_html("Plot.html")

# %%
hook_POOH_600[0]
# Out:
# array([0.00000000e+00, 1.70808179e+02, 6.18882792e+02, 1.02411153e+03,
#        1.12933839e+03, 3.06127170e+03, 3.23267045e+03, 3.72906525e+03,
#        4.16347899e+03, 4.67844708e+03, 5.72327087e+03, 6.38167558e+03,
#        2.79558891e+04, 2.81501450e+04, 7.77918313e+04, 7.80288832e+04,
#        7.85605145e+04, 7.90878252e+04, 1.11292352e+05, 1.13516920e+05,
#        1.16913354e+05, 1.20509396e+05, 1.23883875e+05, 1.27280429e+05,
#        1.30646124e+05, 1.34412748e+05, 2.95960195e+05, 2.98736965e+05,
#        3.03974845e+05, 3.06611289e+05, 3.11613144e+05, 3.13511681e+05,
#        3.15410240e+05, 3.17308713e+05, 3.19207097e+05, 3.21105391e+05,
#        3.23003592e+05, 3.24901700e+05, 3.26799711e+05, 3.28697625e+05,
#        3.30595438e+05, 3.32493150e+05, 3.34390758e+05, 3.36288261e+05,
#        3.38185656e+05, 3.40082942e+05, 3.41980118e+05, 3.43877180e+05,
#        3.45774128e+05, 3.47670960e+05, 3.49567674e+05, 3.51464268e+05,
# ...

# %% [markdown]
# Axial Force Calculation

# %%
from lib.tripping import trip_operation
from lib.circulation import circl
import numpy as np

# Define the range of total lengths
# total_lengths = np.arange(12500, 18001, 100)
total_lengths = [17000]
wob = 0

hook_POOH_470 = np.array([trip_operation(F_b=wob, flowrate=500, length=i, operation='POOH')[-1] for i in total_lengths])
hook_RIH_470 = np.array([trip_operation(F_b=wob, flowrate=500, length=i, operation='RIH')[-1] for i in total_lengths])
hook_ROB_470 = np.array([trip_operation(F_b=wob, flowrate=500, length=i, operation='ROB')[-1] for i in total_lengths])
hook_POOH_250 = np.array([trip_operation(F_b=wob, flowrate=250, length=i, operation='POOH')[-1] for i in total_lengths])
hook_RIH_250 = np.array([trip_operation(F_b=wob, flowrate=250, length=i, operation='RIH')[-1] for i in total_lengths])
hook_ROB_250 = np.array([trip_operation(F_b=wob, flowrate=250, length=i, operation='ROB')[-1] for i in total_lengths])
hook_POOH_0 = np.array([trip_operation(F_b=wob, flowrate=0, length=i, operation='POOH')[-1] for i in total_lengths])
hook_RIH_0 = np.array([trip_operation(F_b=wob, flowrate=0, length=i, operation='RIH')[-1] for i in total_lengths])
hook_ROB_0 = np.array([trip_operation(F_b=wob, flowrate=0, length=i, operation='ROB')[-1] for i in total_lengths])
# Out:
# c:\Users\elh1873\AppData\Local\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Web Extension extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
from lib1.tripping import *
from lib1.circulation import circl

# Define the range of total lengths
# total_lengths = list(range(12500, 18001, 100))
total_lengths = [13000]
wob = 0

POOH_470 = [trip_POOH(wob, ff=0.15, length=i) - circl(flowrate=470, length=i) for i in total_lengths]
RIH_470 = [trip_RIH(wob, ff=0.15, length=i) - circl(flowrate=470, length=i) for i in total_lengths]
ROB_470 = [trip_POOH(wob, ff=0, length=i) - circl(flowrate=470, length=i) for i in total_lengths]
POOH_250 = [trip_POOH(wob, ff=0.15, length=i) - circl(flowrate=250, length=i) for i in total_lengths]
RIH_250 = [trip_RIH(wob, ff=0.15, length=i) - circl(flowrate=250, length=i) for i in total_lengths]
ROB_250 = [trip_POOH(wob, ff=0, length=i) - circl(flowrate=250, length=i) for i in total_lengths]
POOH_0 = [trip_POOH(wob, ff=0.15, length=i) for i in total_lengths]
RIH_0 = [trip_RIH(wob, ff=0.15, length=i) for i in total_lengths]
ROB_0 = [trip_POOH(wob, ff=0, length=i) for i in total_lengths]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from lib1.tripping import *
#       2 from lib1.circulation import circl
#       4 # Define the range of total lengths
#       5 # total_lengths = list(range(12500, 18001, 100))
#
# ModuleNotFoundError: No module named 'lib1'

# %%
hook_POOH_470 = [i.sum() + wob for i in POOH_470]
hook_RIH_470 = [i.sum() + wob for i in RIH_470]
hook_ROB_470 = [i.sum() + wob for i in ROB_470]
hook_POOH_250 = [i.sum() + wob for i in POOH_250]
hook_RIH_250 = [i.sum() + wob for i in RIH_250]
hook_ROB_250 = [i.sum() + wob for i in ROB_250]
hook_POOH_0 = [i.sum() + wob for i in POOH_0]
hook_RIH_0 = [i.sum() + wob for i in RIH_0]
hook_ROB_0 = [i.sum() + wob for i in ROB_0]

# %% [markdown]
# With - sign

# %%
hook_POOH_0, hook_RIH_0, hook_ROB_0

# %%
hook_POOH_0, hook_RIH_0, hook_ROB_0

# %% [markdown]
# Without - sign

# %%
hook_POOH_0, hook_RIH_0, hook_ROB_0

# %%
hook_POOH_0, hook_RIH_0, hook_ROB_0

# %% [markdown]
# Hookload Results - 13000 ft

# %%
hook_POOH_0[0]+20000, hook_POOH_250[0]+20000, hook_POOH_470[0]+20000
# Out:
# (328382.89885831904, 308154.00611508446, 299863.4017939246)

# %%
hook_RIH_0[0]-20000, hook_RIH_250[0]-20000, hook_RIH_470[0]-20000
# Out:
# (255481.1721150264, 237358.4852768013, 229877.088458336)

# %%
hook_ROB_0, hook_ROB_250, hook_ROB_470
# Out:
# (array([291120.47276499]), array([272389.70483966]), array([264941.80619539]))

# %% [markdown]
# Hookload Results - 17000 ft

# %%
hook_POOH_0[0]+20000, hook_POOH_250[0]+20000, hook_POOH_470[0]+20000
# Out:
# (350851.1199714261, 322481.57054550416, 312758.09837233427)

# %%
hook_RIH_0[0]-20000, hook_RIH_250[0]-20000, hook_RIH_470[0]-20000
# Out:
# (248356.405565285, 222379.9692879834, 210026.96793526382)

# %%
hook_ROB_0, hook_ROB_250, hook_ROB_470
# Out:
# (array([296347.48780942]), array([272923.75207587]), array([264401.00148752]))

# %% [markdown]
# Hookload Results - 17000 ft (After mods)

# %%
hook_POOH_0[0]+50000, hook_POOH_250[0]+50000, hook_POOH_470[0]+50000
# Out:
# (337142.6370287888, 302204.101414911, 283036.92312735796)

# %%
hook_RIH_0[0]-50000, hook_RIH_250[0]-50000, hook_RIH_470[0]-50000
# Out:
# (205623.35414375606, 183704.21064196056, 173267.68324368625)

# %%
hook_ROB_0, hook_ROB_250, hook_ROB_470
# Out:
# (array([253134.15480819]), array([232227.66127381]), array([222579.17565085]))

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Scatter(x=total_lengths, y=hook_POOH_470+20000, name='POOH 470 gpm', line=dict(color='darkred', width=3, dash='dashdot')))
fig.add_trace(go.Scatter(x=total_lengths, y=hook_RIH_470-20000, name='RIH 470 gpm', line=dict(color='orange', width=3, dash='dashdot'))) 
fig.add_trace(go.Scatter(x=total_lengths, y=hook_ROB_470, name='ROB 470 gpm', line=dict(color='navy', width=3, dash='dashdot'))) 

fig.add_trace(go.Scatter(x=total_lengths, y=hook_POOH_250+20000, name='POOH 250 gpm', line=dict(color='darkred', width=3, dash='dash')))
fig.add_trace(go.Scatter(x=total_lengths, y=hook_RIH_250-20000, name='RIH 250 gpm', line=dict(color='orange', width=3, dash='dash'))) 
fig.add_trace(go.Scatter(x=total_lengths, y=hook_ROB_250, name='ROB 250 gpm', line=dict(color='navy', width=3, dash='dash'))) 

fig.add_trace(go.Scatter(x=total_lengths, y=hook_POOH_0+20000, name='POOH 0 gpm', line=dict(color='darkred', width=3, dash='dot')))
fig.add_trace(go.Scatter(x=total_lengths, y=hook_RIH_0-20000, name='RIH 0 gpm', line=dict(color='orange', width=3, dash='dot'))) 
fig.add_trace(go.Scatter(x=total_lengths, y=hook_ROB_0, name='ROB 0 gpm', line=dict(color='navy', width=3, dash='dot'))) 

# Update the layout for white background and improved readability
fig.update_xaxes(minor=dict(ticklen=6, tickcolor="black", showgrid=True))
fig.update_yaxes(minor_ticks="inside")
fig.update_layout(
    
    template= "none",
    title='Hookload vs. Bit Depth for Various GPM Rates',  # Add a title
    title_font_size=24,
    xaxis=dict(
        title='Bit Depth [ft]',
        titlefont_size=20,
        tickfont_size=14,
        tickmode = 'linear',
        tick0 = 13000,
        dtick = 500
    ),
    yaxis=dict(
        title='Hookload [lbf]',
        titlefont_size=20,
        tickfont_size=14,
        tickmode = 'linear',
        tick0 = 200000,
        dtick = 10000
    ),
    legend=dict(
        traceorder='normal',
        font=dict(
            size=16,
        )
    ),
    # autosize=True,
    height = 500,
    width = 1000
)

# Show the figure
fig.show()
# fig.write_html("Plot.html")

# %% [markdown]
# Fluif Force Calculation

# %%
from lib1.circulation import circl
import numpy as np
total_lengths = np.arange(12500, 18001, 100)

# %%
flu_470_13k = circl(flowrate=470, length=13000)
flu_250_13k = circl(flowrate=250, length=13000)
flu_470_17k = circl(flowrate=470, length=17000)
flu_250_17k = circl(flowrate=250, length=17000)
flu_250_total = [-circl(flowrate=250, length=i).sum() for i in total_lengths]
flu_470_total = [-circl(flowrate=470, length=i).sum() for i in total_lengths]

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

fig1 = make_subplots(rows=1, cols=2)

fig1.add_trace(go.Scatter(x=flu_470_13k, y=np.linspace(13000,0,len(flu_470_13k)), name='13k @ 470 gpm', line=dict(color='darkred', width=3, dash='dashdot')), row=1, col=1)
fig1.add_trace(go.Scatter(x=flu_250_13k, y=np.linspace(13000,0,len(flu_250_13k)), name='13k @ 250 gpm', line=dict(color='orange', width=3, dash='dashdot')), row=1, col=1)
fig1.add_trace(go.Scatter(x=flu_470_17k, y=np.linspace(17000,0,len(flu_470_17k)), name='17k @ 470 gpm', line=dict(color='navy', width=3, dash='dash')), row=1, col=2)
fig1.add_trace(go.Scatter(x=flu_250_17k, y=np.linspace(17000,0,len(flu_250_17k)), name='17k @ 250 gpm', line=dict(color='teal', width=3, dash='dash')), row=1, col=2)

# Update the layout

fig1.update_layout(
    
    template= "none",
    title='Fluid Force for Various GPM Rates',
    title_font_size=24,
    xaxis=dict(
        title='Fluid Force [lbf]',
        titlefont_size=20
    ),
    yaxis=dict(
        title='Bit Depth [ft]',
        titlefont_size=20,
        autorange="reversed"
    ),
    xaxis2=dict(
        title='Fluid Force [lbf]',
        titlefont_size=20
    ),
    yaxis2=dict(
        title='Bit Depth [ft]',
        titlefont_size=20,
        autorange="reversed"
    ),
    legend=dict(
        traceorder='normal',
        font=dict(
            size=16,
        )
    ),
    height = 600,
    width = 1000
)

fig1.show()
# fig.write_html("Plot.html")

# %%
fig2 = go.Figure()

fig2.add_trace(go.Scatter(x=total_lengths, y=flu_470_total, name='Net Force @ 470 gpm', line=dict(color='slategrey', width=3, dash='dash')))
fig2.add_trace(go.Scatter(x=total_lengths, y=flu_250_total, name='Net Force @ 250 gpm', line=dict(color='orange', width=3, dash='dash')))

# Update the layout
fig2.update_layout(
    template= "none",
    title='Net Fluid Force for different Bit Depths',
    title_font_size=24,
    xaxis=dict(
        title='Bit Depth [ft]',
        titlefont_size=20
    ),
    yaxis=dict(
        title='Fluid Force [lbf]',
        titlefont_size=20
    ),
    legend=dict(
        traceorder='normal',
        font=dict(
            size=16,
        )
    ),
    autosize=True,
)

fig2.show()

# %% [markdown]
# Restriction Check

# %%
from lib.tripping import trip_operation
import numpy as np
# Out:
# c:\Users\Elmir\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Web Extension extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
wob = 0

POOH_470 = np.array(trip_operation(F_b=wob, flowrate=500, length=13000, operation='POOH'))
RIH_470 = np.array(trip_operation(F_b=wob,  flowrate=500, length=13000, operation='RIH'))
ROB_470 = np.array(trip_operation(F_b=wob,  flowrate=500, length=13000, operation='ROB'))
POOH_250 = np.array(trip_operation(F_b=wob, flowrate=250, length=13000, operation='POOH'))
RIH_250 = np.array(trip_operation(F_b=wob,  flowrate=250, length=13000, operation='RIH'))
ROB_250 = np.array(trip_operation(F_b=wob,  flowrate=250, length=13000, operation='ROB'))
POOH_0 = np.array(trip_operation(F_b=wob, flowrate=0, length=13000, operation='POOH'))
RIH_0 = np.array(trip_operation(F_b=wob, flowrate=0, length=13000, operation='RIH'))
ROB_0 = np.array(trip_operation(F_b=wob, flowrate=0, length=13000, operation='ROB'))

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

fig = make_subplots(rows=1, cols=3, subplot_titles=("@ 470 GPM", "@ 250 GPM", "@ 0 GPM"), shared_yaxes=True)

fig.add_trace(go.Scatter(x=POOH_470+70000, y=np.linspace(13000, 0, len(POOH_470)), name='POOH 470 gpm', line=dict(color='darkred', width=3, dash='dashdot')), row=1, col=1)
fig.add_trace(go.Scatter(x=RIH_470+70000, y=np.linspace(13000, 0, len(RIH_470)), name='RIH 470 gpm', line=dict(color='orange', width=3, dash='dashdot')), row=1, col=1) 
fig.add_trace(go.Scatter(x=ROB_470+70000, y=np.linspace(13000, 0, len(ROB_470)), name='ROB 470 gpm', line=dict(color='navy', width=3, dash='dashdot')), row=1, col=1) 
fig.add_trace(go.Scatter(x=POOH_250+70000, y=np.linspace(13000, 0, len(POOH_250)), name='POOH 250 gpm', line=dict(color='sienna', width=3, dash='dash')), row=1, col=2)
fig.add_trace(go.Scatter(x=RIH_250+70000, y=np.linspace(13000, 0, len(RIH_250)), name='RIH 250 gpm', line=dict(color='sandybrown', width=3, dash='dash')), row=1, col=2) 
fig.add_trace(go.Scatter(x=ROB_250+70000, y=np.linspace(13000, 0, len(ROB_250)), name='ROB 250 gpm', line=dict(color='seagreen', width=3, dash='dash')), row=1, col=2) 
fig.add_trace(go.Scatter(x=POOH_0+70000, y=np.linspace(13000, 0, len(POOH_0)), name='POOH 0 gpm', line=dict(color='turquoise', width=3, dash='dot')), row=1, col=3)
fig.add_trace(go.Scatter(x=RIH_0+70000, y=np.linspace(13000, 0, len(RIH_0)), name='RIH 0 gpm', line=dict(color='wheat', width=3, dash='dot')), row=1, col=3) 
fig.add_trace(go.Scatter(x=ROB_0+70000, y=np.linspace(13000, 0, len(ROB_0)), name='ROB 0 gpm', line=dict(color='violet', width=3, dash='dot')), row=1, col=3) 

# Update the layout for white background and improved readability
fig.update_xaxes(minor=dict(ticklen=6, tickcolor="black", showgrid=True))
fig.update_yaxes(minor_ticks="inside")
fig.update_layout(
    
    template= "none",
    title='Axial Force vs. MD for Various GPM Rates',  # Add a title
    title_font_size=24,
    xaxis=dict(
        title='Axial Force [lbf]',
        titlefont_size=20,
        tickfont_size=14
    ),
    yaxis=dict(
        title='MD [ft]',
        titlefont_size=20,
        tickfont_size=14,
        autorange="reversed"
    ),
    legend=dict(
        traceorder='normal',
        font=dict(
            size=16,
        )
    ),
    height = 600,
    width = 1400
)

# Show the figure
fig.show()
# fig.write_html("Plot.html")

# %% [markdown]
# Hookload Results - Closer to the Bit

# %%
POOH_0+20000, POOH_250+20000, POOH_470+20000
# Out:
# (327303.3890616717, 307422.5648260756, 294183.02531721187)

# %%
RIH_0-20000, RIH_250-20000, RIH_470-20000
# Out:
# (255163.46029075357, 237260.4386971984, 224752.63135406972)

# %%
ROB_0, ROB_250, ROB_470
# Out:
# (array(290487.82797127), array(272026.74268909), array(259563.72835863))

# %% [markdown]
# Hookload Results - Further from the bit

# %%
POOH_0+20000, POOH_250+20000, POOH_470+20000
# Out:
# (327302.3503764293, 307782.69388694846, 295836.66643494536)

# %%
RIH_0-20000, RIH_250-20000, RIH_470-20000
# Out:
# (255186.13271226687, 237655.2076077912, 226458.80496666842)

# %%
ROB_0, ROB_250, ROB_470
# Out:
# (array(290497.96624531), array(272401.32755323), array(261231.60225132))

# %%
import plotly.graph_objects as go

trips = ['RIH', 'ROB', 'POOH']
fig = go.Figure()

fig.add_trace(go.Bar(
    x=trips,
    y=[235755, 270835, 305770],
    name='Normal',
    marker_color='indianred',
    text=[235755, 270835, 305770],
    textposition='auto'
))

fig.add_trace(go.Bar(
    x=trips,
    y=[224752, 259564, 294183],
    name='Restriction',
    marker_color='lightsalmon',
    text=[224752, 259564, 294183],
    textposition='auto'
))

fig.update_layout(
    barmode='group', 
    template= "none",
    title='Hookload with and without restriction @ 470 gpm',
    title_font_size=24,
    xaxis=dict(
        titlefont_size=20
    ),
    yaxis=dict(
        title='Hookload [lbf]',
        titlefont_size=20
    ),
    legend=dict(
        traceorder='normal',
        font=dict(
            size=16,
        )
    ),
    height=600, 
    width=800
    )

fig.show()

# %%
import plotly.graph_objects as go

trips = ['RIH', 'ROB', 'POOH']
fig = go.Figure()

fig.add_trace(go.Bar(
    x=trips,
    y=[239923, 274964, 310738],
    name='Normal',
    marker_color='#1D2D44',
    text=[239923, 274964, 310738],
    textposition='auto'
))

fig.add_trace(go.Bar(
    x=trips,
    y=[237655, 272401, 307782],
    name='Restriction',
    marker_color='#748CAB',
    text=[237655, 272401, 307782],
    textposition='auto'
))

fig.update_layout(
    barmode='group', 
    template= "none",
    title='Hookload with and without restriction @ 250 gpm',
    title_font_size=24,
    xaxis=dict(
        titlefont_size=20
    ),
    yaxis=dict(
        title='Hookload [lbf]',
        titlefont_size=20
    ),
    legend=dict(
        traceorder='normal',
        font=dict(
            size=16,
        )
    ),
    height=600, 
    width=800
    )

fig.show()
