# %% [markdown]
# Lib_new == OG BHA configuration (No speed and acceleration effect)

# %%
from lib.tripping import trip_operation

# Define the range of total lengths
# total_lengths = np.arange(12500, 18001, 100)
bit_depth = 13000
wob = 0

hook_POOH_470 = trip_operation(F_b=wob, flowrate=470, length=bit_depth, operation='POOH')[-1]
hook_RIH_470 = trip_operation(F_b=wob, flowrate=470, length=bit_depth, operation='RIH')[-1]
hook_ROB_470 = trip_operation(F_b=wob, flowrate=470, length=bit_depth, operation='ROB')[-1]
hook_POOH_250 = trip_operation(F_b=wob, flowrate=250, length=bit_depth, operation='POOH')[-1]
hook_RIH_250 = trip_operation(F_b=wob, flowrate=250, length=bit_depth, operation='RIH')[-1]
hook_ROB_250 = trip_operation(F_b=wob, flowrate=250, length=bit_depth, operation='ROB')[-1]
hook_POOH_0 = trip_operation(F_b=wob, flowrate=0, length=bit_depth, operation='POOH')[-1]
hook_RIH_0 = trip_operation(F_b=wob, flowrate=0, length=bit_depth, operation='RIH')[-1]
hook_ROB_0 = trip_operation(F_b=wob, flowrate=0, length=bit_depth, operation='ROB')[-1]

# %%
from lib.tripping import trip_operation
bit_depth = 13000
wob = 0
hook_POOH_0, times_POOH_0 = trip_operation(F_b=wob, flowrate=0, length=bit_depth, operation='POOH')
hook_RIH_0, times_RIH_0 = trip_operation(F_b=wob, flowrate=0, length=bit_depth, operation='RIH')
hook_ROB_0, times_ROB_0 = trip_operation(F_b=wob, flowrate=0, length=bit_depth, operation='ROB')
# Out:
# /Users/elmir/anaconda3/lib/python3.11/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Web Extension extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
[i + 60000 for i in hook_POOH_0]
# Out:
# [417478.024355974,
#  416799.50982844154,
#  415479.423806351,
#  414290.00681962713,
#  415180.0246683497,
#  419771.2919599851,
#  426903.79201153805,
#  438188.0326046223,
#  451690.7646120897,
#  467668.91103088134,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  403291.81660543475,
#  196897.8996009251,
#  152515.78038880834,
#  121103.26316981239,
#  103928.3835287436]

# %%
import plotly.graph_objects as go

fig = go.Figure(data=go.Scatter(
    x=times_POOH_0,
    y=hook_POOH_0,
    mode="lines",
    line=dict(color="blue")
))

fig.update_layout(
    template= "gridon",
    title='Hookload vs. Time for POOH @ 0 GPM', 
    title_font_size=24,
    xaxis=dict(
        title='Time [s]',
        titlefont_size=20,
        tickfont_size=14,
        tickmode = 'linear',
        # tick0 = 0,
        dtick = 5
    ),
    yaxis=dict(
        title='Hookload [lbf]',
        titlefont_size=20,
        tickfont_size=14,
        tickmode = 'linear',
        # tick0 = 200000,
        dtick = 50000
    ),
    legend=dict(
        traceorder='normal',
        font=dict(
            size=16,
        )
    ),
    # autosize=True,
    height = 500,
    width = 800
)
fig.show()

# %%
fig = go.Figure(data=go.Scatter(
    x=times_RIH_0,
    y=hook_RIH_0,
    mode="lines",
    line=dict(color="red")
))

fig.update_layout(
    template= "gridon",
    title='Hookload vs. Time for RIH @ 0 GPM', 
    title_font_size=24,
    xaxis=dict(
        title='Time [s]',
        titlefont_size=20,
        tickfont_size=14,
        tickmode = 'linear',
        # tick0 = 0,
        dtick = 5
    ),
    yaxis=dict(
        title='Hookload [lbf]',
        titlefont_size=20,
        tickfont_size=14,
        tickmode = 'linear',
        # tick0 = 200000,
        dtick = 50000
    ),
    legend=dict(
        traceorder='normal',
        font=dict(
            size=16,
        )
    ),
    # autosize=True,
    height = 500,
    width = 800
)
fig.show()

# %%
from lib.constants import Calculations as clc
from lib.topdrive import vel_acc
import plotly.graph_objects as go
import numpy as np

time = np.arange(0,80.1,0.5)
vel, acc = vel_acc(time, clc(depth=13000))

fig = go.Figure()

fig.add_trace(go.Scatter(
    x=time,
    y=vel,
    name='Velocity',
    mode="lines",
    line=dict(color="navy")
))
fig.add_trace(go.Scatter(
    x=time,
    y=acc,
    name='Acceleration',
    mode="lines",
    yaxis='y2',
    line=dict(color="orange")
))

fig.update_layout(
    template= "gridon",
    title='Topdrive velocity and acceleration profiles', 
    title_font_size=24,

    yaxis=dict(title='Velocity [ft/s]',
               titlefont_size=20),
    yaxis2=dict(
        title='Acceleration [ft/s²]',
        titlefont_size=20,
        anchor='x',  # Anchor y-axis to the x-axis
        overlaying='y',  # Overlay y2 on the same x position as y
        side='right'  # Position y2 on the right
    ),
    xaxis=dict(
        title='Time [s]',
        titlefont_size=20
    ),

    # xaxis=dict(
    #     title='Time [s]',
    #     titlefont_size=20,
    #     tickfont_size=14,
    #     tickmode = 'linear',
    #     # tick0 = 0,
    #     dtick = 5
    # ),
    # yaxis=dict(
    #     title='Acceleration [lbf]',
    #     titlefont_size=20,
    #     tickfont_size=14,
    #     tickmode = 'linear',
    #     # tick0 = 200000,
    #     # dtick = 50000
    # ),
    legend=dict(
        x=1,  # Horizontal position at the far left
        y=1,  # Vertical position at the bottom
        xanchor='right',  # Anchor the left side of the legend box
        yanchor='top',  # Anchor the bottom of the legend box
        bgcolor='rgba(255, 255, 255, 0.5)'  # Optional: background color with transparency
    ),
    # autosize=True,
    height = 500,
    width = 800
)
fig.show()

# %% [markdown]
# Hookload Results - 13000 ft

# %%
hook_POOH_0[0]+60000, hook_POOH_250[0]+60000, hook_POOH_470[0]+60000
# Out:
# (324658.63136126375, 307415.994073928, 299060.6312309976)

# %%
hook_RIH_0[0]+20000, hook_RIH_250[0]+20000, hook_RIH_470[0]+20000
# Out:
# (252734.911588639, 236720.94895590554, 228843.815408366)

# %%
hook_ROB_0+40000, hook_ROB_250+40000, hook_ROB_470+40000
# Out:
# (array([287891.26217492]), array([271453.5993665]), array([263414.94759857]))

# %% [markdown]
# Hookload Results - 17000 ft

# %%
hook_POOH_0[0]+60000, hook_POOH_250[0]+60000, hook_POOH_470[0]+60000
# Out:
# (347142.63702885475, 323285.36575813283, 312273.2637748555)

# %%
hook_RIH_0[0]+20000, hook_RIH_250[0]+20000, hook_RIH_470[0]+20000
# Out:
# (245623.3541436932, 223657.11012552254, 213301.57334197478)

# %%
hook_ROB_0+40000, hook_ROB_250+40000, hook_ROB_470+40000
# Out:
# (array([293134.15480819]), array([271975.9985862]), array([262030.11534988]))

# %% [markdown]
# Axial Force Calculation

# %%
from lib.tripping import trip_operation
from lib.circulation import circl
import numpy as np

# Define the range of total lengths
# total_lengths = np.arange(12500, 18001, 100)
bit_depth = [13000]
wob = 0

hook_POOH_470 = np.array([trip_operation(F_b=wob, flowrate=470, length=i, operation='POOH')[-1] for i in bit_depth])
hook_RIH_470 = np.array([trip_operation(F_b=wob, flowrate=470, length=i, operation='RIH')[-1] for i in bit_depth])
hook_ROB_470 = np.array([trip_operation(F_b=wob, flowrate=470, length=i, operation='ROB')[-1] for i in bit_depth])
hook_POOH_250 = np.array([trip_operation(F_b=wob, flowrate=250, length=i, operation='POOH')[-1] for i in bit_depth])
hook_RIH_250 = np.array([trip_operation(F_b=wob, flowrate=250, length=i, operation='RIH')[-1] for i in bit_depth])
hook_ROB_250 = np.array([trip_operation(F_b=wob, flowrate=250, length=i, operation='ROB')[-1] for i in bit_depth])
hook_POOH_0 = np.array([trip_operation(F_b=wob, flowrate=0, length=i, operation='POOH')[-1] for i in bit_depth])
hook_RIH_0 = np.array([trip_operation(F_b=wob, flowrate=0, length=i, operation='RIH')[-1] for i in bit_depth])
hook_ROB_0 = np.array([trip_operation(F_b=wob, flowrate=0, length=i, operation='ROB')[-1] for i in bit_depth])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 11
#       8 wob = 0
#      10 hook_POOH_470 = np.array([trip_operation(F_b=wob, flowrate=470, length=i, operation='POOH')[-1] for i in bit_depth])
# ---> 11 hook_RIH_470 = np.array([trip_operation(F_b=wob, flowrate=470, length=i, operation='RIH')[-1] for i in bit_depth])
#      12 hook_ROB_470 = np.array([trip_operation(F_b=wob, flowrate=470, length=i, operation='ROB')[-1] for i in bit_depth])
#      13 hook_POOH_250 = np.array([trip_operation(F_b=wob, flowrate=250, length=i, operation='POOH')[-1] for i in bit_depth])
#
# Cell In[6], line 11, in <listcomp>(.0)
#       8 wob = 0
#      10 hook_POOH_470 = np.array([trip_operation(F_b=wob, flowrate=470, length=i, operation='POOH')[-1] for i in bit_depth])
# ---> 11 hook_RIH_470 = np.array([trip_operation(F_b=wob, flowrate=470, length=i, operation='RIH')[-1] for i in bit_depth])
#      12 hook_ROB_470 = np.array([trip_operation(F_b=wob, flowrate=470, length=i, operation='ROB')[-1] for i in bit_depth])
#      13 hook_POOH_250 = np.array([trip_operation(F_b=wob, flowrate=250, length=i, operation='POOH')[-1] for i in bit_depth])
#
# File ~/Library/CloudStorage/OneDrive-UniversityofTulsa/PHD/Models/Model_v3.0/lib/tripping.py:57, in trip_operation(F_b, flowrate, length, operation)
#      54 else:
#      55     raise ValueError("Unknown operation type specified.")
# ---> 57 sol = [solve_ivp(dFds,
#      58                 s_span,
#      59                 [F_b],
#      60                 args=(vel[i], acc[i]),
#      61                 method='RK45',
#      62                 t_eval=np.flip(clc.MD),
#      63                 max_step=10,
#      64                 rtol=0.001,
#      65                 atol=0.001,
#      66                 dense_output=True
#      67                 ).y.flatten()[-1] for i,_ in enumerate(times)]
#      69 return sol
#
# File ~/Library/CloudStorage/OneDrive-UniversityofTulsa/PHD/Models/Model_v3.0/lib/tripping.py:57, in <listcomp>(.0)
#      54 else:
#      55     raise ValueError("Unknown operation type specified.")
# ---> 57 sol = [solve_ivp(dFds,
#      58                 s_span,
#      59                 [F_b],
#      60                 args=(vel[i], acc[i]),
#      61                 method='RK45',
#      62                 t_eval=np.flip(clc.MD),
#      63                 max_step=10,
#      64                 rtol=0.001,
#      65                 atol=0.001,
#      66                 dense_output=True
#      67                 ).y.flatten()[-1] for i,_ in enumerate(times)]
#      69 return sol
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/integrate/_ivp/ivp.py:602, in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     600 status = None
#     601 while status is None:
# --> 602     message = solver.step()
#     604     if solver.status == 'finished':
#     605         status = 0
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/integrate/_ivp/base.py:197, in OdeSolver.step(self)
#     195 else:
#     196     t = self.t
# --> 197     success, message = self._step_impl()
#     199     if not success:
#     200         self.status = 'failed'
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/integrate/_ivp/rk.py:144, in RungeKutta._step_impl(self)
#     141 h = t_new - t
#     142 h_abs = np.abs(h)
# --> 144 y_new, f_new = rk_step(self.fun, t, y, self.f, h, self.A,
#     145                        self.B, self.C, self.K)
#     146 scale = atol + np.maximum(np.abs(y), np.abs(y_new)) * rtol
#     147 error_norm = self._estimate_error_norm(self.K, h, scale)
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/integrate/_ivp/rk.py:66, in rk_step(fun, t, y, f, h, A, B, C, K)
#      63     dy = np.dot(K[:s].T, a[:s]) * h
#      64     K[s] = fun(t + c * h, y + dy)
# ---> 66 y_new = y + h * np.dot(K[:-1].T, B)
#      67 f_new = fun(t + h, y_new)
#      69 K[-1] = f_new
#
# File <__array_function__ internals>:177, in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
from lib.tripping import trip_operation

wob = 0
newh = trip_operation(F_b=wob, flowrate=0, length=13000, operation='POOH')
newz = trip_operation(F_b=wob, flowrate=0, length=13000, operation='RIH')
newx = trip_operation(F_b=wob, flowrate=0, length=13000, operation='ROB')

# %%
newz
# Out:
# [190100.20192518385,
#  190203.46971904952,
#  190426.76629791985,
#  190628.4765496385,
#  190747.02247983264,
#  190644.30403758492,
#  190061.6813847387,
#  188598.32020777845,
#  186143.29929408125,
#  182646.89370565876,
#  178363.42113896125,
#  173081.50658870282,
#  166551.5731425335,
#  159320.67763985196,
#  151465.91836153044,
#  143014.99779402773,
#  133969.66149763262,
#  124340.94555229886,
#  114132.3971009825,
#  103300.68752704463,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  139089.4711810298,
#  -18160.16444588058,
#  17577.504830637215,
#  46738.12735963031,
#  68880.38549867105,
#  83651.78113656594,
#  88629.1127966943]

# %%
from lib.tripping_opt import trip_operation

wob = 0
newh1 = trip_operation(F_b=wob, flowrate=470, length=13000, operation='POOH')
newz1 = trip_operation(F_b=wob, flowrate=470, length=13000, operation='RIH')
newx1 = trip_operation(F_b=wob, flowrate=470, length=13000, operation='ROB')

# %%
newh[-1], newz[-1], newx[-1]
# Out:
# (308499.70375864534, 275585.5149305317, 291230.7392499788)

# %%
newh1[-1], newz1[-1], newx1[-1]
# Out:
# (275104.6966843412, 213013.123887449, 247072.94565673338)

# %%
from lib1.tripping import *
from lib1.circulation import circl

# Define the range of total lengths
# total_lengths = list(range(12500, 18001, 100))
total_lengths = [13000]
wob = 0

POOH_470 = [trip_POOH(wob, ff=0.15, length=i) - circl(flowrate=470, length=i) for i in total_lengths]
RIH_470 = [trip_RIH(wob, ff=0.15, length=i) - circl(flowrate=470, length=i) for i in total_lengths]
ROB_470 = [trip_POOH(wob, ff=0, length=i) - circl(flowrate=470, length=i) for i in total_lengths]
POOH_250 = [trip_POOH(wob, ff=0.15, length=i) - circl(flowrate=250, length=i) for i in total_lengths]
RIH_250 = [trip_RIH(wob, ff=0.15, length=i) - circl(flowrate=250, length=i) for i in total_lengths]
ROB_250 = [trip_POOH(wob, ff=0, length=i) - circl(flowrate=250, length=i) for i in total_lengths]
POOH_0 = [trip_POOH(wob, ff=0.15, length=i) for i in total_lengths]
RIH_0 = [trip_RIH(wob, ff=0.15, length=i) for i in total_lengths]
ROB_0 = [trip_POOH(wob, ff=0, length=i) for i in total_lengths]

# %%
hook_POOH_470 = [i.sum() + wob for i in POOH_470]
hook_RIH_470 = [i.sum() + wob for i in RIH_470]
hook_ROB_470 = [i.sum() + wob for i in ROB_470]
hook_POOH_250 = [i.sum() + wob for i in POOH_250]
hook_RIH_250 = [i.sum() + wob for i in RIH_250]
hook_ROB_250 = [i.sum() + wob for i in ROB_250]
hook_POOH_0 = [i.sum() + wob for i in POOH_0]
hook_RIH_0 = [i.sum() + wob for i in RIH_0]
hook_ROB_0 = [i.sum() + wob for i in ROB_0]

# %% [markdown]
# With - sign

# %%
hook_POOH_0, hook_RIH_0, hook_ROB_0

# %%
hook_POOH_0, hook_RIH_0, hook_ROB_0

# %% [markdown]
# Without - sign

# %%
hook_POOH_0, hook_RIH_0, hook_ROB_0

# %%
hook_POOH_0, hook_RIH_0, hook_ROB_0

# %% [markdown]
# Hookload Results - 13000 ft

# %%
hook_POOH_0[0]+20000, hook_POOH_250[0]+20000, hook_POOH_470[0]+20000

# %%
hook_RIH_0[0]-20000, hook_RIH_250[0]-20000, hook_RIH_470[0]-20000

# %%
hook_ROB_0, hook_ROB_250, hook_ROB_470

# %% [markdown]
# Hookload Results - 17000 ft

# %%
hook_POOH_0[0]+20000, hook_POOH_250[0]+20000, hook_POOH_470[0]+20000

# %%
hook_RIH_0[0]-20000, hook_RIH_250[0]-20000, hook_RIH_470[0]-20000

# %%
hook_ROB_0, hook_ROB_250, hook_ROB_470

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Scatter(x=total_lengths, y=hook_POOH_470+20000, name='POOH 470 gpm', line=dict(color='darkred', width=3, dash='dashdot')))
fig.add_trace(go.Scatter(x=total_lengths, y=hook_RIH_470-20000, name='RIH 470 gpm', line=dict(color='orange', width=3, dash='dashdot'))) 
fig.add_trace(go.Scatter(x=total_lengths, y=hook_ROB_470, name='ROB 470 gpm', line=dict(color='navy', width=3, dash='dashdot'))) 

fig.add_trace(go.Scatter(x=total_lengths, y=hook_POOH_250+20000, name='POOH 250 gpm', line=dict(color='darkred', width=3, dash='dash')))
fig.add_trace(go.Scatter(x=total_lengths, y=hook_RIH_250-20000, name='RIH 250 gpm', line=dict(color='orange', width=3, dash='dash'))) 
fig.add_trace(go.Scatter(x=total_lengths, y=hook_ROB_250, name='ROB 250 gpm', line=dict(color='navy', width=3, dash='dash'))) 

fig.add_trace(go.Scatter(x=total_lengths, y=hook_POOH_0+20000, name='POOH 0 gpm', line=dict(color='darkred', width=3, dash='dot')))
fig.add_trace(go.Scatter(x=total_lengths, y=hook_RIH_0-20000, name='RIH 0 gpm', line=dict(color='orange', width=3, dash='dot'))) 
fig.add_trace(go.Scatter(x=total_lengths, y=hook_ROB_0, name='ROB 0 gpm', line=dict(color='navy', width=3, dash='dot'))) 

# Update the layout for white background and improved readability
fig.update_xaxes(minor=dict(ticklen=6, tickcolor="black", showgrid=True))
fig.update_yaxes(minor_ticks="inside")
fig.update_layout(
    
    template= "none",
    title='Hookload vs. Bit Depth for Various GPM Rates',  # Add a title
    title_font_size=24,
    xaxis=dict(
        title='Bit Depth [ft]',
        titlefont_size=20,
        tickfont_size=14,
        tickmode = 'linear',
        tick0 = 13000,
        dtick = 500
    ),
    yaxis=dict(
        title='Hookload [lbf]',
        titlefont_size=20,
        tickfont_size=14,
        tickmode = 'linear',
        tick0 = 200000,
        dtick = 10000
    ),
    legend=dict(
        traceorder='normal',
        font=dict(
            size=16,
        )
    ),
    # autosize=True,
    height = 500,
    width = 1000
)

# Show the figure
fig.show()
# fig.write_html("Plot.html")

# %% [markdown]
# Fluif Force Calculation

# %%
from lib1.circulation import circl
import numpy as np
total_lengths = np.arange(12500, 18001, 100)

# %%
flu_470_13k = circl(flowrate=470, length=13000)
flu_250_13k = circl(flowrate=250, length=13000)
flu_470_17k = circl(flowrate=470, length=17000)
flu_250_17k = circl(flowrate=250, length=17000)
flu_250_total = [-circl(flowrate=250, length=i).sum() for i in total_lengths]
flu_470_total = [-circl(flowrate=470, length=i).sum() for i in total_lengths]

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

fig1 = make_subplots(rows=1, cols=2)

fig1.add_trace(go.Scatter(x=flu_470_13k, y=np.linspace(13000,0,len(flu_470_13k)), name='13k @ 470 gpm', line=dict(color='darkred', width=3, dash='dashdot')), row=1, col=1)
fig1.add_trace(go.Scatter(x=flu_250_13k, y=np.linspace(13000,0,len(flu_250_13k)), name='13k @ 250 gpm', line=dict(color='orange', width=3, dash='dashdot')), row=1, col=1)
fig1.add_trace(go.Scatter(x=flu_470_17k, y=np.linspace(17000,0,len(flu_470_17k)), name='17k @ 470 gpm', line=dict(color='navy', width=3, dash='dash')), row=1, col=2)
fig1.add_trace(go.Scatter(x=flu_250_17k, y=np.linspace(17000,0,len(flu_250_17k)), name='17k @ 250 gpm', line=dict(color='teal', width=3, dash='dash')), row=1, col=2)

# Update the layout

fig1.update_layout(
    
    template= "none",
    title='Fluid Force for Various GPM Rates',
    title_font_size=24,
    xaxis=dict(
        title='Fluid Force [lbf]',
        titlefont_size=20
    ),
    yaxis=dict(
        title='Bit Depth [ft]',
        titlefont_size=20,
        autorange="reversed"
    ),
    xaxis2=dict(
        title='Fluid Force [lbf]',
        titlefont_size=20
    ),
    yaxis2=dict(
        title='Bit Depth [ft]',
        titlefont_size=20,
        autorange="reversed"
    ),
    legend=dict(
        traceorder='normal',
        font=dict(
            size=16,
        )
    ),
    height = 600,
    width = 1000
)

fig1.show()
# fig.write_html("Plot.html")

# %%
fig2 = go.Figure()

fig2.add_trace(go.Scatter(x=total_lengths, y=flu_470_total, name='Net Force @ 470 gpm', line=dict(color='slategrey', width=3, dash='dash')))
fig2.add_trace(go.Scatter(x=total_lengths, y=flu_250_total, name='Net Force @ 250 gpm', line=dict(color='orange', width=3, dash='dash')))

# Update the layout
fig2.update_layout(
    template= "none",
    title='Net Fluid Force for different Bit Depths',
    title_font_size=24,
    xaxis=dict(
        title='Bit Depth [ft]',
        titlefont_size=20
    ),
    yaxis=dict(
        title='Fluid Force [lbf]',
        titlefont_size=20
    ),
    legend=dict(
        traceorder='normal',
        font=dict(
            size=16,
        )
    ),
    autosize=True,
)

fig2.show()

# %% [markdown]
# Restriction Check

# %%
from lib1.tripping_opt import trip_operation
import numpy as np

# %%
wob = 0

POOH_470 = np.array(trip_operation(F_b=wob, ff=0.15, flowrate=470, length=13000, operation='POOH')[-1])
RIH_470 = np.array(trip_operation(F_b=wob, ff=0.15, flowrate=470, length=13000, operation='RIH')[-1])
ROB_470 = np.array(trip_operation(F_b=wob, ff=0.15, flowrate=470, length=13000, operation='ROB')[-1])
POOH_250 = np.array(trip_operation(F_b=wob, ff=0.15, flowrate=250, length=13000, operation='POOH')[-1])
RIH_250 = np.array(trip_operation(F_b=wob, ff=0.15, flowrate=250, length=13000, operation='RIH')[-1])
ROB_250 = np.array(trip_operation(F_b=wob, ff=0.15, flowrate=250, length=13000, operation='ROB')[-1])
POOH_0 = np.array(trip_operation(F_b=wob, ff=0.15, flowrate=0, length=13000, operation='POOH')[-1])
RIH_0 = np.array(trip_operation(F_b=wob, ff=0.15, flowrate=0, length=13000, operation='RIH')[-1])
ROB_0 = np.array(trip_operation(F_b=wob, ff=0.15, flowrate=0, length=13000, operation='ROB')[-1])

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

fig = make_subplots(rows=1, cols=3, subplot_titles=("@ 470 GPM", "@ 250 GPM", "@ 0 GPM"), shared_yaxes=True)

fig.add_trace(go.Scatter(x=POOH_470[0], y=np.linspace(13000, 0, len(POOH_470[0])), name='POOH 470 gpm', line=dict(color='darkred', width=3, dash='dashdot')), row=1, col=1)
fig.add_trace(go.Scatter(x=RIH_470[0], y=np.linspace(13000, 0, len(RIH_470[0])), name='RIH 470 gpm', line=dict(color='orange', width=3, dash='dashdot')), row=1, col=1) 
fig.add_trace(go.Scatter(x=ROB_470[0], y=np.linspace(13000, 0, len(ROB_470[0])), name='ROB 470 gpm', line=dict(color='navy', width=3, dash='dashdot')), row=1, col=1) 
fig.add_trace(go.Scatter(x=POOH_250[0], y=np.linspace(13000, 0, len(POOH_250[0])), name='POOH 250 gpm', line=dict(color='sienna', width=3, dash='dash')), row=1, col=2)
fig.add_trace(go.Scatter(x=RIH_250[0], y=np.linspace(13000, 0, len(RIH_250[0])), name='RIH 250 gpm', line=dict(color='sandybrown', width=3, dash='dash')), row=1, col=2) 
fig.add_trace(go.Scatter(x=ROB_250[0], y=np.linspace(13000, 0, len(ROB_250[0])), name='ROB 250 gpm', line=dict(color='seagreen', width=3, dash='dash')), row=1, col=2) 
fig.add_trace(go.Scatter(x=POOH_0[0], y=np.linspace(13000, 0, len(POOH_0[0])), name='POOH 0 gpm', line=dict(color='turquoise', width=3, dash='dot')), row=1, col=3)
fig.add_trace(go.Scatter(x=RIH_0[0], y=np.linspace(13000, 0, len(RIH_0[0])), name='RIH 0 gpm', line=dict(color='wheat', width=3, dash='dot')), row=1, col=3) 
fig.add_trace(go.Scatter(x=ROB_0[0], y=np.linspace(13000, 0, len(ROB_0[0])), name='ROB 0 gpm', line=dict(color='violet', width=3, dash='dot')), row=1, col=3) 

# Update the layout for white background and improved readability
fig.update_xaxes(minor=dict(ticklen=6, tickcolor="black", showgrid=True))
fig.update_yaxes(minor_ticks="inside")
fig.update_layout(
    
    template= "none",
    title='Axial Force vs. MD for Various GPM Rates',  # Add a title
    title_font_size=24,
    xaxis=dict(
        title='Axial Force [lbf]',
        titlefont_size=20,
        tickfont_size=14
    ),
    yaxis=dict(
        title='MD [ft]',
        titlefont_size=20,
        tickfont_size=14,
        autorange="reversed"
    ),
    legend=dict(
        traceorder='normal',
        font=dict(
            size=16,
        )
    ),
    height = 600,
    width = 1400
)

# Show the figure
fig.show()
# fig.write_html("Plot.html")

# %% [markdown]
# Hookload Results - Closer to the Bit

# %%
POOH_0+20000, POOH_250+20000, POOH_470+20000

# %%
RIH_0-20000, RIH_250-20000, RIH_470-20000

# %%
ROB_0, ROB_250, ROB_470

# %% [markdown]
# Hookload Results - Further from the bit

# %%
POOH_0+20000, POOH_250+20000, POOH_470+20000

# %%
RIH_0-20000, RIH_250-20000, RIH_470-20000

# %%
ROB_0, ROB_250, ROB_470

# %%
import plotly.graph_objects as go

trips = ['RIH', 'ROB', 'POOH']
fig = go.Figure()

fig.add_trace(go.Bar(
    x=trips,
    y=[235755, 270835, 305770],
    name='Normal',
    marker_color='indianred',
    text=[235755, 270835, 305770],
    textposition='auto'
))

fig.add_trace(go.Bar(
    x=trips,
    y=[224752, 259564, 294183],
    name='Restriction',
    marker_color='lightsalmon',
    text=[224752, 259564, 294183],
    textposition='auto'
))

fig.update_layout(
    barmode='group', 
    template= "none",
    title='Hookload with and without restriction @ 470 gpm',
    title_font_size=24,
    xaxis=dict(
        titlefont_size=20
    ),
    yaxis=dict(
        title='Hookload [lbf]',
        titlefont_size=20
    ),
    legend=dict(
        traceorder='normal',
        font=dict(
            size=16,
        )
    ),
    height=600, 
    width=800
    )

fig.show()

# %%
import plotly.graph_objects as go

trips = ['RIH', 'ROB', 'POOH']
fig = go.Figure()

fig.add_trace(go.Bar(
    x=trips,
    y=[239923, 274964, 310738],
    name='Normal',
    marker_color='#1D2D44',
    text=[239923, 274964, 310738],
    textposition='auto'
))

fig.add_trace(go.Bar(
    x=trips,
    y=[237655, 272401, 307782],
    name='Restriction',
    marker_color='#748CAB',
    text=[237655, 272401, 307782],
    textposition='auto'
))

fig.update_layout(
    barmode='group', 
    template= "none",
    title='Hookload with and without restriction @ 250 gpm',
    title_font_size=24,
    xaxis=dict(
        titlefont_size=20
    ),
    yaxis=dict(
        title='Hookload [lbf]',
        titlefont_size=20
    ),
    legend=dict(
        traceorder='normal',
        font=dict(
            size=16,
        )
    ),
    height=600, 
    width=800
    )

fig.show()
